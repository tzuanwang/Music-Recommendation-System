# %%
import os
import json
import random
import pandas as pd

# %%
# Path to the folder containing JSON files
json_folder = "data/spotify_million_playlist_dataset/data"

# %%
# Initialize a list to store all playlists
all_playlists = []

# %%
# Loop through all JSON files in the folder
for filename in os.listdir(json_folder):
    if filename.endswith(".json"):
        file_path = os.path.join(json_folder, filename)
        
        # Open and load the JSON file
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)  # Each file contains a dictionary with "playlists" key
            
            # Check if 'playlists' key exists and is a list
            playlists = data.get("playlists", [])
            if not isinstance(playlists, list):
                print(f"Unexpected playlists structure in file {filename}")
                continue
            
            # Filter playlists with num_tracks <= 40 and add them to the list
            for playlist in playlists:
                if playlist.get("num_tracks", 0) <= 40:
                    all_playlists.append(playlist)
                    if len(all_playlists) == 4000:  # Stop once 4000 playlists are collected
                        break
        
        if len(all_playlists) == 4000:  # Stop processing files if we have 4000 playlists
            break

# %%
all_playlists[0]
# Out:
# {'name': 'August',
#  'collaborative': 'false',
#  'pid': 549003,
#  'modified_at': 1505001600,
#  'num_tracks': 38,
#  'num_albums': 32,
#  'num_followers': 1,
#  'tracks': [{'pos': 0,
#    'artist_name': 'C-Trox',
#    'track_uri': 'spotify:track:44uuZDQFAtfag94mDPIsEu',
#    'artist_uri': 'spotify:artist:1MWyFWQ7erF4XjLph84x5J',
#    'track_name': 'Passionate',
#    'album_uri': 'spotify:album:1eJGL3iCFGrc0O34Wh57cA',
#    'duration_ms': 206001,
#    'album_name': 'Passionate'},
#   {'pos': 1,
#    'artist_name': 'Watsky',
#    'track_uri': 'spotify:track:0Vwfd6fxFrL3kCnZSJ9vid',
#    'artist_uri': 'spotify:artist:3mJ9GlkLzj8Ka7Z7EQaCMi',
#    'track_name': 'Sloppy Seconds',
#    'album_uri': 'spotify:album:2zgb2l9pexGdZkM5pGuwb9',
#    'duration_ms': 245933,
#    'album_name': 'Cardboard Castles'},
#   {'pos': 2,
#    'artist_name': 'Maritime',
#    'track_uri': 'spotify:track:2Ze0YvSXz8CnC81hw5rXNo',
#    'artist_uri': 'spotify:artist:79xu36jzq3a5nU8uubNZr9',
#    'track_name': 'Roaming Empire',
#    'album_uri': 'spotify:album:3A2rsJIXswjqBHa9digdCb',
#    'duration_ms': 234960,
#    'album_name': 'Magnetic Bodies/Maps of Bones'},
#   {'pos': 3,
#    'artist_name': 'RY X',
#    'track_uri': 'spotify:track:34hMOtKwf5nm8tjvkGV0Dk',
#    'artist_uri': 'spotify:artist:2KjAo6wVc9d2WcxdxSArpV',
#    'track_name': 'Howling',
#    'album_uri': 'spotify:album:0DvauBOn2G8RIEQR54Cmiv',
#    'duration_ms': 309590,
#    'album_name': 'Dawn'},
#   {'pos': 4,
#    'artist_name': 'Liam Payne',
#    'track_uri': 'spotify:track:6EpRaXYhGOB3fj4V2uDkMJ',
#    'artist_uri': 'spotify:artist:5pUo3fmmHT8bhCyHE52hA6',
#    'track_name': 'Strip That Down',
#    'album_uri': 'spotify:album:2mnDyPSNM02LMvniaMWnLl',
#    'duration_ms': 204502,
#    'album_name': 'Strip That Down'},
#   {'pos': 5,
#    'artist_name': 'ZAYN',
#    'track_uri': 'spotify:track:6lvsJDZ7336YmpBzcNGhbe',
#    'artist_uri': 'spotify:artist:5ZsFI1h6hIdQRw2ti0hz81',
#    'track_name': 'fOoL fOr YoU',
#    'album_uri': 'spotify:album:5amj9zNeZ3B2EdpBgXrOZ0',
#    'duration_ms': 202213,
#    'album_name': 'Mind Of Mine (Deluxe Edition)'},
#   {'pos': 6,
#    'artist_name': 'Bad Suns',
#    'track_uri': 'spotify:track:41d2Q6DHcM20OdzynkRtvf',
#    'artist_uri': 'spotify:artist:0YhUSm86okLWldQVwJkLlP',
#    'track_name': 'Daft Pretty Boys',
#    'album_uri': 'spotify:album:2YXl7mV4d30fEbwpVQ7YBQ',
#    'duration_ms': 187013,
#    'album_name': 'Disappear Here'},
#   {'pos': 7,
#    'artist_name': 'The Kite String Tangle',
#    'track_uri': 'spotify:track:07Y1uIQqxFbvSKzqLzqJQb',
#    'artist_uri': 'spotify:artist:3D6cosC5ZOLCpRxt6T3XS7',
#    'track_name': 'Arcadia',
#    'album_uri': 'spotify:album:3qt3WDEimDqZ9VFCdPEb21',
#    'duration_ms': 213936,
#    'album_name': 'Vessel'},
#   {'pos': 8,
#    'artist_name': 'Hozier',
#    'track_uri': 'spotify:track:44f2AVSNQ3xVs1EI0S0bjl',
#    'artist_uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS',
#    'track_name': 'Like Real People Do',
#    'album_uri': 'spotify:album:36k5aXpxffjVGcNce12GLZ',
#    'duration_ms': 198029,
#    'album_name': 'Hozier'},
#   {'pos': 9,
#    'artist_name': 'Lin-Manuel Miranda',
#    'track_uri': 'spotify:track:4cxvludVmQxryrnx1m9FqL',
#    'artist_uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N',
#    'track_name': 'My Shot',
#    'album_uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc',
#    'duration_ms': 333154,
#    'album_name': 'Hamilton'},
#   {'pos': 10,
#    'artist_name': 'Matthew Schuler',
#    'track_uri': 'spotify:track:1p6IRFj7G6Z3lQeHsTGidD',
#    'artist_uri': 'spotify:artist:6FSZmn4oKr0o1UpTZ8vXMq',
#    'track_name': 'Cough Syrup - The Voice Performance',
#    'album_uri': 'spotify:album:2KlCTNUEog4jXW4UAMGkY4',
#    'duration_ms': 214368,
#    'album_name': 'Cough Syrup'},
#   {'pos': 11,
#    'artist_name': 'Ashton Edminster',
#    'track_uri': 'spotify:track:5UQWcrjEY7BRYydYO4qOOT',
#    'artist_uri': 'spotify:artist:3tnwxF4S1AA8x7nhPwLYY8',
#    'track_name': 'Shades of Blue',
#    'album_uri': 'spotify:album:3TsdYBuv549rlzYebzcqT1',
#    'duration_ms': 253422,
#    'album_name': 'Shades of Blue'},
#   {'pos': 12,
#    'artist_name': 'James Blake',
#    'track_uri': 'spotify:track:03CLsFk6JSz301bKuukPSD',
#    'artist_uri': 'spotify:artist:53KwLdlmrlCelAZMaLVZqU',
#    'track_name': 'Retrograde',
#    'album_uri': 'spotify:album:12ExNn0hx85F8UNzoKCyCD',
#    'duration_ms': 223600,
#    'album_name': 'Overgrown'},
#   {'pos': 13,
#    'artist_name': 'Colbie Caillat',
#    'track_uri': 'spotify:track:3wVVIeC1tLfBxXtISoBZaA',
#    'artist_uri': 'spotify:artist:6aZyMrc4doVtZyKNilOmwu',
#    'track_name': 'When The Darkness Comes',
#    'album_uri': 'spotify:album:2BLgCI5sxPWSQGMB3B3Ogf',
#    'duration_ms': 256346,
#    'album_name': 'The Mortal Instruments: City of Bones (Original Motion Picture Soundtrack)'},
#   {'pos': 14,
#    'artist_name': 'Lorde',
#    'track_uri': 'spotify:track:60jI0JgMLLj1VggHJVhtRs',
#    'artist_uri': 'spotify:artist:163tK9Wjr9P9DmM0AVK7lm',
#    'track_name': 'Glory And Gore',
#    'album_uri': 'spotify:album:0rmhjUgoVa17LZuS8xWQ3v',
#    'duration_ms': 210737,
#    'album_name': 'Pure Heroine'},
#   {'pos': 15,
#    'artist_name': 'Gentle Bones',
#    'track_uri': 'spotify:track:5fiac7SW61qWXs2hSj3bE4',
#    'artist_uri': 'spotify:artist:4jGPdu95icCKVF31CcFKbS',
#    'track_name': 'Settle Down',
#    'album_uri': 'spotify:album:2UHTzL8WkOnvwxNwwGVGvI',
#    'duration_ms': 220480,
#    'album_name': 'Gentle Bones'},
#   {'pos': 16,
#    'artist_name': 'John Buckley',
#    'track_uri': 'spotify:track:7jqdD1NL36KXsbJ4XeOw3N',
#    'artist_uri': 'spotify:artist:5dID7TuTjqElOjVuFYCJ9o',
#    'track_name': 'Festival',
#    'album_uri': 'spotify:album:1UaMSNMWDczKRwKnp4QZDm',
#    'duration_ms': 208972,
#    'album_name': 'Festival'},
#   {'pos': 17,
#    'artist_name': 'The Wombats',
#    'track_uri': 'spotify:track:1OqbX2MZ6ZzWP7HjMHbdkp',
#    'artist_uri': 'spotify:artist:0Ya43ZKWHTKkAbkoJJkwIB',
#    'track_name': 'Pink Lemonade',
#    'album_uri': 'spotify:album:0XOseclZGO4NnaBz5Shjxp',
#    'duration_ms': 226106,
#    'album_name': 'Glitterbug'},
#   {'pos': 18,
#    'artist_name': 'Eden Project',
#    'track_uri': 'spotify:track:6NiXAdF2005XfIrbJ2JCN9',
#    'artist_uri': 'spotify:artist:26plsJBmW5se3wurhwzaEK',
#    'track_name': 'XO',
#    'album_uri': 'spotify:album:10dfkctY9SVtrkWmG0mzHE',
#    'duration_ms': 159582,
#    'album_name': 'XO'},
#   {'pos': 19,
#    'artist_name': 'Bad Luck',
#    'track_uri': 'spotify:track:6XD3BF0gYW5cfuhQornwNQ',
#    'artist_uri': 'spotify:artist:4Hjb6XIYNt5Qkokl30luY9',
#    'track_name': 'Love Song',
#    'album_uri': 'spotify:album:6AUd3bhTVxj30xYJO9cAWK',
#    'duration_ms': 120523,
#    'album_name': 'Noise In Your Head'},
#   {'pos': 20,
#    'artist_name': 'Declan McKenna',
#    'track_uri': 'spotify:track:74lfGn1j0rBJ3YqR2mo4oU',
#    'artist_uri': 'spotify:artist:2D4FOOOtWycb3Aw9nY5n3c',
#    'track_name': 'Paracetamol',
#    'album_uri': 'spotify:album:3HJiLDJgWA9Z0MvCxlzHYQ',
#    'duration_ms': 318373,
#    'album_name': 'What Do You Think About the Car?'},
#   {'pos': 21,
#    'artist_name': 'Hozier',
#    'track_uri': 'spotify:track:2Tjlq3aGhg3dIZFvSfsnyc',
#    'artist_uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS',
#    'track_name': 'From Eden',
#    'album_uri': 'spotify:album:36k5aXpxffjVGcNce12GLZ',
#    'duration_ms': 283466,
#    'album_name': 'Hozier'},
#   {'pos': 22,
#    'artist_name': 'The Front Bottoms',
#    'track_uri': 'spotify:track:3AWyIxWrWWa9lM1wk8hmKn',
#    'artist_uri': 'spotify:artist:5ictveRyhWRs8Gt8Dvt1hS',
#    'track_name': 'Peach',
#    'album_uri': 'spotify:album:3Whyz0vsFG5AdcSzlgC3k0',
#    'duration_ms': 185853,
#    'album_name': 'Talon Of The Hawk'},
#   {'pos': 23,
#    'artist_name': 'The Maine',
#    'track_uri': 'spotify:track:3oe574OaDVi0qyTyk8PNaX',
#    'artist_uri': 'spotify:artist:4o0pNHbyj36LPvukNqEug0',
#    'track_name': 'Another Night On Mars',
#    'album_uri': 'spotify:album:2B2vHCKcHod82FCaFtkm1u',
#    'duration_ms': 266405,
#    'album_name': 'American Candy'},
#   {'pos': 24,
#    'artist_name': 'Olivver the Kid',
#    'track_uri': 'spotify:track:1Z3tVvYtzrzxFnXf43ityG',
#    'artist_uri': 'spotify:artist:3SoOohS0zlj8nLdGmhrKA7',
#    'track_name': '4 AM',
#    'album_uri': 'spotify:album:62PZju3SrH8QY0xou2aHmF',
#    'duration_ms': 175815,
#    'album_name': 'The Boy Who Cried Wolf'},
#   {'pos': 25,
#    'artist_name': 'Jonathan Groff',
#    'track_uri': 'spotify:track:6OG1S805gIrH5nAQbEOPY3',
#    'artist_uri': 'spotify:artist:7KkqUt65v6LMtR369OQ6FB',
#    'track_name': "You'll Be Back",
#    'album_uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc',
#    'duration_ms': 208321,
#    'album_name': 'Hamilton'},
#   {'pos': 26,
#    'artist_name': 'Thomston',
#    'track_uri': 'spotify:track:1jvweZLzDnuvOHMFA7J5oA',
#    'artist_uri': 'spotify:artist:0VQKssIfRKfSd7IfW3JIP1',
#    'track_name': 'Anaesthetic',
#    'album_uri': 'spotify:album:0gIM5JccfKC3XSVGoJxhgS',
#    'duration_ms': 261072,
#    'album_name': 'Argonaut - EP'},
#   {'pos': 27,
#    'artist_name': 'Thomston',
#    'track_uri': 'spotify:track:5mC49xHCGRNSBM4uksa7Tc',
#    'artist_uri': 'spotify:artist:0VQKssIfRKfSd7IfW3JIP1',
#    'track_name': 'Caffeine',
#    'album_uri': 'spotify:album:0gIM5JccfKC3XSVGoJxhgS',
#    'duration_ms': 291550,
#    'album_name': 'Argonaut - EP'},
#   {'pos': 28,
#    'artist_name': 'X Ambassadors',
#    'track_uri': 'spotify:track:7lGKEWMXVWWTt3X71Bv44I',
#    'artist_uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB',
#    'track_name': 'Unsteady',
#    'album_uri': 'spotify:album:7A8fZ2jjiu5heq7wNCutKN',
#    'duration_ms': 193546,
#    'album_name': 'VHS'},
#   {'pos': 29,
#    'artist_name': 'Denim Blue & Miclain Keith',
#    'track_uri': 'spotify:track:2efjWH6ePBZOwvpQcgi2m1',
#    'artist_uri': 'spotify:artist:1XK7PcHslf4GR1y13VSNuJ',
#    'track_name': 'Pills',
#    'album_uri': 'spotify:album:38iLYsGfLlG8yITks7plOe',
#    'duration_ms': 206769,
#    'album_name': 'Collapse'},
#   {'pos': 30,
#    'artist_name': 'Imagine Dragons',
#    'track_uri': 'spotify:track:0tKcYR2II1VCQWT79i5NrW',
#    'artist_uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q',
#    'track_name': 'Thunder',
#    'album_uri': 'spotify:album:5GlPAy2PRJW06GVFhKwGTl',
#    'duration_ms': 187146,
#    'album_name': 'Evolve'},
#   {'pos': 31,
#    'artist_name': 'XXXTENTACION',
#    'track_uri': 'spotify:track:7m9OqQk4RVRkw9JJdeAw96',
#    'artist_uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4',
#    'track_name': 'Jocelyn Flores',
#    'album_uri': 'spotify:album:5VdyJkLe3yvOs0l4xXbWp0',
#    'duration_ms': 119133,
#    'album_name': '17'},
#   {'pos': 32,
#    'artist_name': 'Thomston',
#    'track_uri': 'spotify:track:0jHRla4jXwIi7ZcdaIj5o8',
#    'artist_uri': 'spotify:artist:0VQKssIfRKfSd7IfW3JIP1',
#    'track_name': 'Motley Crew',
#    'album_uri': 'spotify:album:0gIM5JccfKC3XSVGoJxhgS',
#    'duration_ms': 222234,
#    'album_name': 'Argonaut - EP'},
#   {'pos': 33,
#    'artist_name': 'Thomston',
#    'track_uri': 'spotify:track:1uupttL8z8rSNM9DpMWO52',
#    'artist_uri': 'spotify:artist:0VQKssIfRKfSd7IfW3JIP1',
#    'track_name': 'Burning Out',
#    'album_uri': 'spotify:album:0gIM5JccfKC3XSVGoJxhgS',
#    'duration_ms': 209755,
#    'album_name': 'Argonaut - EP'},
#   {'pos': 34,
#    'artist_name': 'Thomston',
#    'track_uri': 'spotify:track:2qFAGKvY5dNQOdJJfwtXVc',
#    'artist_uri': 'spotify:artist:0VQKssIfRKfSd7IfW3JIP1',
#    'track_name': 'Salt',
#    'album_uri': 'spotify:album:0gIM5JccfKC3XSVGoJxhgS',
#    'duration_ms': 234278,
#    'album_name': 'Argonaut - EP'},
#   {'pos': 35,
#    'artist_name': 'Wei Congfei',
#    'track_uri': 'spotify:track:7yehVUMr5CjCzFoQYDg7Tb',
#    'artist_uri': 'spotify:artist:2dd6B3Uhzim5ttqmISX9ez',
#    'track_name': 'Bluestone Alley',
#    'album_uri': 'spotify:album:4BqQ9Dnm8vAatCsYtE4Hy1',
#    'duration_ms': 227390,
#    'album_name': 'Bluestone Alley'},
#   {'pos': 36,
#    'artist_name': 'Taylor Swift',
#    'track_uri': 'spotify:track:6uFsE1JgZ20EXyU0JQZbUR',
#    'artist_uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02',
#    'track_name': 'Look What You Made Me Do',
#    'album_uri': 'spotify:album:7qqYU64i563QXANa6vpkSr',
#    'duration_ms': 211859,
#    'album_name': 'Look What You Made Me Do'},
#   {'pos': 37,
#    'artist_name': 'American Authors',
#    'track_uri': 'spotify:track:4dHbvCkrv6E5Wx4tvfp4FW',
#    'artist_uri': 'spotify:artist:0MlOPi3zIDMVrfA9R04Fe3',
#    'track_name': "I'm Born To Run",
#    'album_uri': 'spotify:album:34Yb6fymvHaOVlhOKoQ9fM',
#    'duration_ms': 206920,
#    'album_name': 'What We Live For'}],
#  'num_edits': 20,
#  'duration_ms': 8439352,
#  'num_artists': 33}

# %%
len(all_playlists)
# Out:
# 4000

# %%
# Initialize a list to store flattened data
flattened_data = []

# %%
# Flatten the data
for playlist in all_playlists:
    for track in playlist["tracks"]:
        flattened_data.append({
            "pid": playlist["pid"],
            "name": playlist["name"],
            "artist_name": track["artist_name"],
            "artist_uri": track["artist_uri"],
            "track_name": track["track_name"],
            "track_uri": track["track_uri"],
            "album_uri": track["album_uri"],
            "duration_ms": track["duration_ms"],
            "album_name": track["album_name"]
        })

# %%
# Convert the flattened data to a pandas DataFrame
df = pd.DataFrame(flattened_data)

# %%
df.head(5)
# Out:
#       pid    name artist_name                             artist_uri  \
# 0  549003  August      C-Trox  spotify:artist:1MWyFWQ7erF4XjLph84x5J
# 1  549003  August      Watsky  spotify:artist:3mJ9GlkLzj8Ka7Z7EQaCMi
# 2  549003  August    Maritime  spotify:artist:79xu36jzq3a5nU8uubNZr9
# 3  549003  August        RY X  spotify:artist:2KjAo6wVc9d2WcxdxSArpV
# 4  549003  August  Liam Payne  spotify:artist:5pUo3fmmHT8bhCyHE52hA6
#
#         track_name                             track_uri  \
# 0       Passionate  spotify:track:44uuZDQFAtfag94mDPIsEu
# 1   Sloppy Seconds  spotify:track:0Vwfd6fxFrL3kCnZSJ9vid
# 2   Roaming Empire  spotify:track:2Ze0YvSXz8CnC81hw5rXNo
# 3          Howling  spotify:track:34hMOtKwf5nm8tjvkGV0Dk
# 4  Strip That Down  spotify:track:6EpRaXYhGOB3fj4V2uDkMJ
#
#                               album_uri  duration_ms  \
# 0  spotify:album:1eJGL3iCFGrc0O34Wh57cA       206001
# 1  spotify:album:2zgb2l9pexGdZkM5pGuwb9       245933
# 2  spotify:album:3A2rsJIXswjqBHa9digdCb       234960
# 3  spotify:album:0DvauBOn2G8RIEQR54Cmiv       309590
# 4  spotify:album:2mnDyPSNM02LMvniaMWnLl       204502
#
#                       album_name
# 0                     Passionate
# 1              Cardboard Castles
# 2  Magnetic Bodies/Maps of Bones
# 3                           Dawn
# 4                Strip That Down

# %%
total_songs = len(df)
total_songs
# Out:
# 91598

# %%
df['track_id'] = df['track_uri'].str.split(':').str[2]

# %%
df.head(5)
# Out:
#       pid    name artist_name                             artist_uri  \
# 0  549003  August      C-Trox  spotify:artist:1MWyFWQ7erF4XjLph84x5J
# 1  549003  August      Watsky  spotify:artist:3mJ9GlkLzj8Ka7Z7EQaCMi
# 2  549003  August    Maritime  spotify:artist:79xu36jzq3a5nU8uubNZr9
# 3  549003  August        RY X  spotify:artist:2KjAo6wVc9d2WcxdxSArpV
# 4  549003  August  Liam Payne  spotify:artist:5pUo3fmmHT8bhCyHE52hA6
#
#         track_name                             track_uri  \
# 0       Passionate  spotify:track:44uuZDQFAtfag94mDPIsEu
# 1   Sloppy Seconds  spotify:track:0Vwfd6fxFrL3kCnZSJ9vid
# 2   Roaming Empire  spotify:track:2Ze0YvSXz8CnC81hw5rXNo
# 3          Howling  spotify:track:34hMOtKwf5nm8tjvkGV0Dk
# 4  Strip That Down  spotify:track:6EpRaXYhGOB3fj4V2uDkMJ
#
#                               album_uri  duration_ms  \
# 0  spotify:album:1eJGL3iCFGrc0O34Wh57cA       206001
# 1  spotify:album:2zgb2l9pexGdZkM5pGuwb9       245933
# 2  spotify:album:3A2rsJIXswjqBHa9digdCb       234960
# 3  spotify:album:0DvauBOn2G8RIEQR54Cmiv       309590
# 4  spotify:album:2mnDyPSNM02LMvniaMWnLl       204502
#
#                       album_name                track_id
# 0                     Passionate  44uuZDQFAtfag94mDPIsEu
# 1              Cardboard Castles  0Vwfd6fxFrL3kCnZSJ9vid
# 2  Magnetic Bodies/Maps of Bones  2Ze0YvSXz8CnC81hw5rXNo
# 3                           Dawn  34hMOtKwf5nm8tjvkGV0Dk
# 4                Strip That Down  6EpRaXYhGOB3fj4V2uDkMJ

# %%
df.to_csv(f'4000_playlists_{total_songs}.csv')

# %%
df[df['track_id']=='3JOF9NzQVkUXtCcJbEQuAb']
# Out:
#          pid    name       artist_name                             artist_uri  \
# 2204  549197     Lol  Willamette Stone  spotify:artist:19gmxCK2V3jLMi5fDYyKtS
# 6394  549623  Chillz  Willamette Stone  spotify:artist:19gmxCK2V3jLMi5fDYyKtS
# 6395  549623  Chillz  Willamette Stone  spotify:artist:19gmxCK2V3jLMi5fDYyKtS
#
#             track_name                             track_uri  \
# 2204  Heart Like Yours  spotify:track:3JOF9NzQVkUXtCcJbEQuAb
# 6394  Heart Like Yours  spotify:track:3JOF9NzQVkUXtCcJbEQuAb
# 6395  Heart Like Yours  spotify:track:3JOF9NzQVkUXtCcJbEQuAb
#
#                                  album_uri  duration_ms  \
# 2204  spotify:album:2cpfXsbsHVNweQ4USbO6wu       199960
# 6394  spotify:album:2cpfXsbsHVNweQ4USbO6wu       199960
# 6395  spotify:album:2cpfXsbsHVNweQ4USbO6wu       199960
#
#                                           album_name                track_id
# 2204  If I Stay (Original Motion Picture Soundtrack)  3JOF9NzQVkUXtCcJbEQuAb
# 6394  If I Stay (Original Motion Picture Soundtrack)  3JOF9NzQVkUXtCcJbEQuAb
# 6395  If I Stay (Original Motion Picture Soundtrack)  3JOF9NzQVkUXtCcJbEQuAb
